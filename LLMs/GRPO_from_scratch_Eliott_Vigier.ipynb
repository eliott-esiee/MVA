# %% [markdown]
# # GRPO Training project: teach an LLM to do additions, again

# %% [markdown]
# In this notebook, you'll find:
# * A basic Transformer with basic tokenizer
# * A basic dataset for additions
# * A classical pre-trainer, minimizing cross entropy loss
# * A Vanilla GRPO

# %% [markdown]
# You're not supposed to edit the existing code (you can if you want to...).
# You should implement one (or more) of the following:
# * GRPO with PPO (the `usual` one)
# * RLOO
# * ReMax
# * DPO
# * RAFT
# * your own RLHF method!

# %%
import torch
from torch import nn
from torch.nn import functional as F

import random
import math
import re
import time

# %%
num_digits = 3

dataset_size = 64_000
train_proportion = 0.9

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## Step 1: Construct a tokenizer

# %%
pad_token="[PAD]"
eos_token="[EOS]"

# %%
class character_level_tokenizer:
    """
    character-level
    """
    def __init__(self):
        self.vocab = [str(x) for x in range(10)] + ["+", "="] + [pad_token, eos_token]
        self.token_to_id = {v : k for k, v in enumerate(self.vocab)}
        self.id_to_token = {k : v for k, v in enumerate(self.vocab)}
        self.ntokens = len(self.vocab)
        self.pattern = f"[^{re.escape(''.join(self.vocab))}]"

    def clean(self, text):
        """
        removes all characters not in the vocabulary
        """
        out = re.sub(self.pattern, "", text)
        return out

    def pre_tokenization(self, text):
        """
        character-level
        """
        return [c for c in text]

    def encode(self, text):
        text_list = self.pre_tokenization(self.clean(text))
        return [self.token_to_id[c] for c in text_list]

    def decode(self, token_list):
        return "".join([self.id_to_token[x] for x in token_list])

# %%
tokenizer = character_level_tokenizer()
ntokens = tokenizer.ntokens
ntokens
# Out:
# 14

# %%
prompt = "12 + 42 ="
inputs = tokenizer.encode(prompt)
inputs, tokenizer.decode(inputs)
# Out:
# ([1, 2, 10, 4, 2, 11], '12+42=')

# %% [markdown]
# ## Step 2: Create a dataset for arithmetic operations

# %%
def sample_datapoint(num_digits = 3):
    a_list = [random.randint(0, 9) for _ in range(num_digits)]
    b_list = [random.randint(0, 9) for _ in range(num_digits)]
    a_int = int("".join([str(x) for x in a_list]))
    b_int = int("".join([str(x) for x in b_list]))
    a_str = "".join([str(x) for x in a_list])
    b_str = "".join([str(x) for x in b_list])
    sum_int = a_int + b_int
    return (a_str + "+" + b_str + "=", str(sum_int))

sample_datapoint(3)
# Out:
# ('181+924=', '1105')

# %%
data = []
for _ in range(dataset_size):
    data.append(sample_datapoint(num_digits))
data[:4]
# Out:
# [('991+555=', '1546'),
#  ('066+523=', '589'),
#  ('023+342=', '365'),
#  ('213+176=', '389')]

# %%
data_train = data[: int(train_proportion * dataset_size)]
data_test = data[int(train_proportion * dataset_size):]

len(data_train),len(data_test)
# Out:
# (57600, 6400)

# %% [markdown]
# ## Step 3: Construct a model

# %%
class PositionalEncoding(nn.Module):
    r"""Inject some information about the relative or absolute position of the tokens in the sequence.
        The positional encodings have the same dimension as the embeddings, so that the two can be summed.
        Here, we use sine and cosine functions of different frequencies.
    .. math:
        \text{PosEncoder}(pos, 2i) = sin(pos/10000^(2i/d_model))
        \text{PosEncoder}(pos, 2i+1) = cos(pos/10000^(2i/d_model))
        \text{where pos is the word position and i is the embed idx)
    Args:
        d_model: the embed dim (required).
        dropout: the dropout value (default=0.1).
        max_len: the max. length of the incoming sequence (default=5000).
    """

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        r"""Inputs of forward function
        Args:
            x: the sequence fed to the positional encoder model (required).
        Shape:
            x: [sequence length, batch size, embed dim]
            output: [sequence length, batch size, embed dim]
        """

        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
class TransformerModel(nn.Transformer):
    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__(d_model=ninp,
                                               nhead=nhead,
                                               dim_feedforward=nhid,
                                               num_encoder_layers=nlayers)
        self.input_emb = nn.Embedding(ntoken, ninp)
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        self.decoder = nn.Linear(ninp, ntoken)

        self.ninp = ninp
        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.input_emb.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def _generate_square_subsequent_mask(self, sz):
        return torch.log(torch.tril(torch.ones(sz,sz)))

    def forward(self, src):
        mask = self._generate_square_subsequent_mask(len(src)).to(device)
        self.src_mask = mask

        src = self.input_emb(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output_enc = self.encoder(src, mask=self.src_mask)
        output_dec = self.decoder(output_enc)
        return F.log_softmax(output_dec, dim=-1), output_enc

# %%
model = TransformerModel(ntoken = ntokens,
                         ninp = 128,
                         nhead = 16,
                         nhid = 64,
                         nlayers = 8)
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# TransformerModel(
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-7): 8 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=64, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=64, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): Linear(in_features=128, out_features=14, bias=True)
#   (input_emb): Embedding(14, 128)
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
print("number of parameters: {}".format(sum([x.numel() for x in model.parameters()])))
# Out:
# number of parameters: 668942

# %% [markdown]
# ### Useful functions

# %%
def generate(model, prompts, new_tokens = 5, mode = "greedy", num_samples = 1, temperature = 0.8):
    input_tensor = torch.repeat_interleave(prompts, repeats = num_samples, dim = 1).to(device)
    # (prompt_length, batch_size * num_samples)
    for _ in range(new_tokens):
        output, _ = model(input_tensor) # (prompt_length, batch_size * num_samples, ntokens)
        logits = output[-1,:,:] # (batch_size * num_samples, ntokens)
        if mode == "greedy":
            tokens = torch.argmax(logits, -1).view((1,-1)) # (1, batch_size * num_samples)
        else: # mode == "sampling"
            logits /= temperature
            probs = torch.softmax(logits, dim=-1)
            tokens = torch.multinomial(probs, num_samples = 1).view((1,-1)) # (1, batch_size * num_samples)
        input_tensor = torch.cat((input_tensor, tokens), 0)
    return input_tensor

# %%
model.eval()

prompt = "2+3="
prompt_tensor = torch.tensor(tokenizer.encode(prompt)).view((-1,1))
output = generate(model, prompt_tensor).view((1,-1))
output, tokenizer.decode(output[0].tolist())
# Out:
# (tensor([[ 2, 10,  3, 11,  0,  0,  0,  0,  0]], device='cuda:0'), '2+3=00000')

# %%
def pad(token_list, type_list = "prompts"):
    max_length = max([len(x) for x in token_list])
    out = []
    for x in token_list:
        if type_list == "prompts":
            out.append([tokenizer.token_to_id[pad_token]] * (max_length - len(x)) + x)
        if type_list == "answers":
            out.append(x + [tokenizer.token_to_id[eos_token]] + [tokenizer.token_to_id[pad_token]] * (max_length - len(x)))
    return out, max_length

# %%
prompts = [tokenizer.encode("1+1="), tokenizer.encode("21+35=")]
answers = [tokenizer.encode("2"), tokenizer.encode("56")]
padded_prompts, _ = pad(prompts, "prompts")
padded_answers, _ = pad(answers, "answers")
padded_prompts, padded_answers
[tokenizer.decode(p) for p in padded_prompts], [tokenizer.decode(p) for p in padded_answers]
# Out:
# (['[PAD][PAD]1+1=', '21+35='], ['2[EOS][PAD]', '56[EOS]'])

# %%
def get_batch(split, i, batch_size):
    data = data_train if split == 'train' else data_test

    prompts = [data[i][0] for i in range(i, i + batch_size)]
    encoded_prompts = [tokenizer.encode(prompt) for prompt in prompts]
    padded_prompts, prompt_length = pad(encoded_prompts, "prompts")

    answers = [data[i][1] for i in range(i, i + batch_size)]
    encoded_answers = [tokenizer.encode(answer) for answer in answers]
    padded_answers, answers_length = pad(encoded_answers, "answers")

    X = torch.stack([torch.tensor(x) for x in padded_prompts], 1)
    Y = torch.stack([torch.tensor(x) for x in padded_answers], 1)
    return X, Y, prompt_length, answers_length, prompts, answers

# %%
X, Y, prompt_length, answers_length, prompts, answers = get_batch("train", 43, 16)
X.shape, Y.shape, prompt_length, answers_length, prompts[0], answers[0]
# Out:
# (torch.Size([8, 16]), torch.Size([5, 16]), 8, 4, '974+322=', '1296')

# %% [markdown]
# ## Step 4: Evaluate

# %%
batch_size = 16

# %%
def evaluate(batch_size = batch_size):
    # Turn on evaluation mode disables dropout.
    model.eval()
    correct = 0.
    with torch.no_grad():
        for batch, i in enumerate(range(0, len(data_test) - 1, batch_size)):
            prompts, target_answers, prompt_length, answers_length, _, _ = get_batch("test", i, batch_size)
            prompts = prompts.to(device) # (prompt_length, batch_size)
            target_answers = target_answers.to(device) # (answers_length + 1, batch_size)
            output = generate(model, prompts, answers_length + 1) # (prompt_length + answers_length + 1, batch_size)
            answers_tokens = output[prompt_length:, :] # (answers_length + 1, batch_size), contains tokens
            equality_test = answers_tokens == target_answers # (answers_length + 1, batch_size), contains boolean values
            correct += torch.all(equality_test, axis=0).float().sum()
        accuracy = correct / len(data_test)
    return accuracy.item()

# %%
evaluate()
# Out:
# 0.0

# %% [markdown]
# ## Step 5: Train the model, classical approach

# %% [markdown]
# ### Hyperparameters

# %%
epochs = 5
batch_size = 16
learning_rate = 8e-4

reporting_per_epoch = 5
log_interval = len(data_train) // (reporting_per_epoch + 1)
assert(log_interval % batch_size == 0)

# %%
def train():
    model.train()
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    best_test_accuracy = None
    test_accuracy = evaluate()
    print('-' * 89)
    print('| initialisation | test accuracy {:5.2f}'.format(test_accuracy))
    print('-' * 89)
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        total_loss = 0.
        start_time = time.time()
        for batch, i in enumerate(range(0, len(data_train) - 1, batch_size)):
            prompts, target_answers, prompt_length, answers_length, _, _ = get_batch("train", i, batch_size)
            prompts = prompts.to(device) # (prompt_length, batch_size)
            target_answers = target_answers.to(device) # (answers_length + 1, batch_size)
            input_tensor = torch.cat((prompts, target_answers), 0) # (prompt_length + answers_length + 1, batch_size)
            model.zero_grad()
            output, _ = model(input_tensor) # (prompt_length + answers_length + 1, batch_size, ntokens)
            output_answers = output[prompt_length-1:-1,:,:].reshape(-1, ntokens) # ((answers_length + 1) * batch_size, ntokens)
            target_answers = target_answers.view(-1)
            loss = F.cross_entropy(output_answers, target_answers)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if i % log_interval == 0 and batch > 0:
                cur_loss = total_loss / log_interval
                elapsed = time.time() - start_time
                print('| {:5d}/{:5d} batches | ms/batch {:5.2f} | loss {:5.2f} | perplexity {:8.2f}'.format(batch, len(data_train) // batch_size,
                                                                                                            elapsed * 1000 / log_interval, cur_loss, math.exp(cur_loss)))
                total_loss = 0
                start_time = time.time()
        test_accuracy = evaluate()
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | test accuracy {:5.2f}'.format(epoch, (time.time() - epoch_start_time), test_accuracy))
        print('-' * 89)
        # Save the model if the test accuracy is the best we've seen so far.
        if not best_test_accuracy or test_accuracy < best_test_accuracy:
            with open("arithmetic.pt", 'wb') as f:
                torch.save(model, f)
            best_test_accuracy = test_accuracy

# %%
train()
# Out:
# -----------------------------------------------------------------------------------------
# | initialisation | test accuracy  0.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch  1.08 | loss  0.09 | perplexity     1.09
# |  1200/ 3600 batches | ms/batch  1.04 | loss  0.07 | perplexity     1.07
# |  1800/ 3600 batches | ms/batch  1.03 | loss  0.07 | perplexity     1.07
# |  2400/ 3600 batches | ms/batch  1.07 | loss  0.07 | perplexity     1.07
# |  3000/ 3600 batches | ms/batch  1.03 | loss  0.07 | perplexity     1.07
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 69.62s | test accuracy  0.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch  1.04 | loss  0.06 | perplexity     1.07
# |  1200/ 3600 batches | ms/batch  1.02 | loss  0.06 | perplexity     1.07
# |  1800/ 3600 batches | ms/batch  1.04 | loss  0.06 | perplexity     1.07
# |  2400/ 3600 batches | ms/batch  1.08 | loss  0.06 | perplexity     1.07
# |  3000/ 3600 batches | ms/batch  1.03 | loss  0.06 | perplexity     1.06
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 69.51s | test accuracy  0.02
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch  1.06 | loss  0.05 | perplexity     1.05
# |  1200/ 3600 batches | ms/batch  1.04 | loss  0.05 | perplexity     1.05
# |  1800/ 3600 batches | ms/batch  1.07 | loss  0.05 | perplexity     1.05
# |  2400/ 3600 batches | ms/batch  1.05 | loss  0.05 | perplexity     1.05
# |  3000/ 3600 batches | ms/batch  1.05 | loss  0.04 | perplexity     1.04
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 70.25s | test accuracy  0.07
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch  1.01 | loss  0.04 | perplexity     1.04
# |  1200/ 3600 batches | ms/batch  1.06 | loss  0.04 | perplexity     1.04
# |  1800/ 3600 batches | ms/batch  1.02 | loss  0.03 | perplexity     1.04
# |  2400/ 3600 batches | ms/batch  1.02 | loss  0.03 | perplexity     1.03
# |  3000/ 3600 batches | ms/batch  1.04 | loss  0.04 | perplexity     1.04
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 68.85s | test accuracy  0.37
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch  1.03 | loss  0.03 | perplexity     1.03
# |  1200/ 3600 batches | ms/batch  1.06 | loss  0.01 | perplexity     1.01
# |  1800/ 3600 batches | ms/batch  1.03 | loss  0.01 | perplexity     1.01
# |  2400/ 3600 batches | ms/batch  1.03 | loss  0.01 | perplexity     1.01
# |  3000/ 3600 batches | ms/batch  1.06 | loss  0.01 | perplexity     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 69.22s | test accuracy  0.91
# -----------------------------------------------------------------------------------------

# %%
model.eval()

for i in range(20):
    prompt, answers = data_test[i]
    prompt_tensor = torch.tensor(tokenizer.encode(prompt)).view((-1,1))
    output = generate(model, prompt_tensor, len(answers) + 1).view((1,-1))
    print(tokenizer.decode(output.tolist()[0]) + "\t actual result: " + answers)
# Out:
# 422+311=733[EOS]	 actual result: 733
# 645+238=883[EOS]	 actual result: 883
# 704+212=916[EOS]	 actual result: 916
# 367+325=692[EOS]	 actual result: 692
# 878+223=1100[EOS]	 actual result: 1101
# 841+462=1303[EOS]	 actual result: 1303
# 383+908=1291[EOS]	 actual result: 1291
# 542+484=1026[EOS]	 actual result: 1026
# 590+687=1277[EOS]	 actual result: 1277
# 066+988=1054[EOS]	 actual result: 1054
# 354+948=1302[EOS]	 actual result: 1302
# 782+151=933[EOS]	 actual result: 933
# 660+866=1526[EOS]	 actual result: 1526
# 738+419=1157[EOS]	 actual result: 1157
# 618+437=1055[EOS]	 actual result: 1055
# 985+343=1328[EOS]	 actual result: 1328
# 461+569=1030[EOS]	 actual result: 1030
# 861+561=1422[EOS]	 actual result: 1422
# 260+981=1241[EOS]	 actual result: 1241
# 085+095=180[EOS]	 actual result: 180

# %% [markdown]
# ## Step 4 bis: Vanilla GRPO training

# %% [markdown]
# ### Custom reward functions

# %%
def accuracy_reward(output, answer):
    pattern = r"\[EOS\]"
    output = re.sub(pattern, "", output)
    pattern = r"(\[PAD\])*$"
    output = re.sub(pattern, "", output)
    return 1. if output == answer else 0.

accuracy_reward("123[EOS][PAD][PAD]", "123"), accuracy_reward("123", "124"),
# Out:
# (1.0, 0.0)

# %%
def distance_accuracy_reward(output, answer):
    pattern = r"\[EOS\]"
    output = re.sub(pattern, "", output)
    pattern = r"(\[PAD\])*$"
    output = re.sub(pattern, "", output)
    int_output = int(output)
    int_answer = int(answer)
    return abs(int_output - int_answer) / max(int_output, int_answer)

distance_accuracy_reward("123[EOS]", "123"), distance_accuracy_reward("123[PAD]", "124"),
# Out:
# (0.0, 0.008064516129032258)

# %%
def digit_accuracy_reward(output, answer):
    pattern = r"\[EOS\]"
    output = re.sub(pattern, "", output)
    pattern = r"(\[PAD\])*$"
    output = re.sub(pattern, "", output)
    return sum(c1 == c2 for (c1,c2) in zip(output, answer)) / max(len(output), len(answer))

digit_accuracy_reward("123[EOS][PAD][PAD]", "123"), digit_accuracy_reward("123[EOS]", "123"),
# Out:
# (1.0, 1.0)

# %%
def reward_format(output):
    pattern = r"\d+\[EOS\](\[PAD\])*$"
    return 1. if bool(re.match(pattern, output)) else 0.

reward_format("123[EOS][PAD][PAD]"), reward_format("123[EOS]"), reward_format("123"),
# Out:
# (1.0, 1.0, 0.0)

# %% [markdown]
# ### Hyperparameters

# %%
epochs = 20
batch_size = 16
learning_rate = 1e-4
num_samples = 16
temperature = .8

reporting_per_epoch = 5
log_interval = len(data_train) // (reporting_per_epoch + 1)
assert(log_interval % batch_size == 0)

reward_fun = digit_accuracy_reward
reward_format = reward_format

# %%
def compute_rewards(text_outputs, answers):
    repeated_answers = [answer for answer in answers for _ in range(num_samples)]
    rewards = torch.tensor(
        [0.2 * reward_format(output) + 0.8 * reward_fun(output, answer)
         for output, answer in zip(text_outputs, repeated_answers)],
        dtype=torch.float32,
        device=device
    )
    return rewards

# %%
def calculate_grpo_advantages(rewards):
    # reshape rewards to group by prompt
    # compute mean and standard deviation for each prompt group
    mean_rewards = rewards.view(-1, num_samples).mean(dim=1)
    std_rewards = rewards.view(-1, num_samples).std(dim=1)
    # expand the means and stds to match the original flat rewards tensor shape
    mean_rewards = mean_rewards.repeat_interleave(num_samples, dim=0)
    std_rewards = std_rewards.repeat_interleave(num_samples, dim=0)
    # normalize rewards to get advantages
    advantages = (rewards - mean_rewards) / (std_rewards + 1e-5)
    return advantages

# %%
def compute_log_probs(model, outputs, prompt_length):
    logits, _ = model(outputs)
    # logits.shape = (prompt_length + answers_length + 1, batch_size * num_samples, vocab_size)

    # we only need the log probabilities for the new tokens
    # this introduces a shift: the logits for a position are the predictions for the next token
    logits = logits[prompt_length-1:-1, :, :]
    # logits.shape = (answers_length + 1, batch_size * num_samples, vocab_size)

    # convert raw logits into log probabilities along the vocabulary axis
    log_probs = F.log_softmax(logits, dim=-1)
    # log_probs.shape = (answers_length + 1, batch_size * num_samples, vocab_size)
    return log_probs

# %%
def compute_loss(advantages, log_probs, responses):
    # reshape responses from (answers_length + 1, batch_size * num_samples)
    # to (answers_length + 1, batch_size * num_samples, 1) for gathering
    responses = responses.unsqueeze(-1)
    # log_probs.shape = (answers_length + 1, batch_size * num_samples, vocab_size)
    # responses.shape = (answers_length + 1, batch_size * num_samples)
    # gather the log probability for each token in responses
    selected_log_probs = log_probs.gather(dim=-1, index=responses)
    # remove the extra last dimension to get back to shape (answers_length + 1, batch_size * num_samples).
    selected_log_probs = selected_log_probs.squeeze(-1)

    # normalize
    selected_log_probs = (selected_log_probs - selected_log_probs.mean(-1, keepdim=True)) / (selected_log_probs.std(-1, keepdim=True) + 1e-5)

    # advantages.shape = (batch_size * num_samples)
    # we use the same advantages for all tokens in the response
    loss = -(advantages.unsqueeze(dim=0) * selected_log_probs).mean()
    return loss

# %%
def train_vanilla_GRPO(verbose = False):
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    best_test_accuracy = None
    test_accuracy = evaluate()
    print('-' * 89)
    print('| initialisation | test accuracy {:5.2f}'.format(test_accuracy))
    print('-' * 89)

    # switch eval for train model (enables dropout)
    model.train()

    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        start_time = time.time()
        for batch, i in enumerate(range(0, len(data_train) - 1, batch_size)):

            # get a batch of prompts and answers
            prompts, _, prompt_length, answers_length, questions, answers = get_batch("train", i, batch_size)
            prompts = prompts.to(device) # (prompt_length, batch_size)

            # generate samples for each prompt
            outputs = generate(model,
                               prompts,
                               new_tokens = answers_length + 1,
                               mode = "sampling",
                               num_samples = num_samples,
                               temperature = temperature)
            # outputs.shape = (prompt_length + answers_length + 1, batch_size * num_samples)
            text_outputs = [tokenizer.decode(outputs[prompt_length:, i].tolist())
                            for i in range(outputs.size(1))]

            # compute rewards
            rewards = compute_rewards(text_outputs, answers)

            # compute advantages
            advantages = calculate_grpo_advantages(rewards)

            # compute log probabilities
            log_probs = compute_log_probs(model, outputs, prompt_length)

            # compute loss
            responses = outputs[prompt_length:, :]
            loss = compute_loss(advantages, log_probs, responses)

            # optimize
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            if i % log_interval == 0 and batch > 0:
                elapsed = time.time() - start_time
                print('| {:5d}/{:5d} batches | ms/batch {:5.2f}'.format(batch, len(data_train) // batch_size, elapsed))
                if verbose:
                    print("\nquestion:", questions[0],
                      "\nanswer", answers[0],
                      "\noutput:", text_outputs[:num_samples],
                      "\nreward:", rewards[:num_samples],
                      "\nadvantage:", advantages[:num_samples], "\n")

                start_time = time.time()
        test_accuracy = evaluate()
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | test accuracy {:5.2f}'.format(epoch, (time.time() - epoch_start_time), test_accuracy))
        print('-' * 89)
        # Save the model if the test accuracy is the best we've seen so far.
        if not best_test_accuracy or test_accuracy < best_test_accuracy:
            with open("arithmetic_vanilla_GRPO.pt", 'wb') as f:
                torch.save(model, f)
            best_test_accuracy = test_accuracy

# %%
train_vanilla_GRPO(verbose = False)
# Out:
# -----------------------------------------------------------------------------------------
# | initialisation | test accuracy  0.91
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 54.30
# |  1200/ 3600 batches | ms/batch 53.63
# |  1800/ 3600 batches | ms/batch 53.60
# |  2400/ 3600 batches | ms/batch 53.48
# |  3000/ 3600 batches | ms/batch 53.58
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 330.97s | test accuracy  0.54
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.94
# |  1200/ 3600 batches | ms/batch 50.43
# |  1800/ 3600 batches | ms/batch 50.52
# |  2400/ 3600 batches | ms/batch 50.45
# |  3000/ 3600 batches | ms/batch 50.42
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 312.35s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.83
# |  1200/ 3600 batches | ms/batch 50.39
# |  1800/ 3600 batches | ms/batch 50.53
# |  2400/ 3600 batches | ms/batch 50.51
# |  3000/ 3600 batches | ms/batch 50.48
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 312.20s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.81
# |  1200/ 3600 batches | ms/batch 50.37
# |  1800/ 3600 batches | ms/batch 50.49
# |  2400/ 3600 batches | ms/batch 50.43
# |  3000/ 3600 batches | ms/batch 50.42
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 312.05s | test accuracy  0.98
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.80
# |  1200/ 3600 batches | ms/batch 50.37
# |  1800/ 3600 batches | ms/batch 50.55
# |  2400/ 3600 batches | ms/batch 50.34
# |  3000/ 3600 batches | ms/batch 50.37
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 312.15s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.80
# |  1200/ 3600 batches | ms/batch 50.22
# |  1800/ 3600 batches | ms/batch 50.41
# |  2400/ 3600 batches | ms/batch 50.41
# |  3000/ 3600 batches | ms/batch 50.46
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 311.93s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.75
# |  1200/ 3600 batches | ms/batch 50.24
# |  1800/ 3600 batches | ms/batch 50.37
# |  2400/ 3600 batches | ms/batch 50.36
# |  3000/ 3600 batches | ms/batch 50.40
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 311.34s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.72
# |  1200/ 3600 batches | ms/batch 50.24
# |  1800/ 3600 batches | ms/batch 50.38
# |  2400/ 3600 batches | ms/batch 50.35
# |  3000/ 3600 batches | ms/batch 50.48
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 311.63s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.73
# |  1200/ 3600 batches | ms/batch 50.19
# |  1800/ 3600 batches | ms/batch 50.42
# |  2400/ 3600 batches | ms/batch 50.27
# |  3000/ 3600 batches | ms/batch 50.47
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 311.30s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.79
# |  1200/ 3600 batches | ms/batch 50.22
# |  1800/ 3600 batches | ms/batch 50.36
# |  2400/ 3600 batches | ms/batch 50.39
# |  3000/ 3600 batches | ms/batch 50.45
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 311.43s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.76
# |  1200/ 3600 batches | ms/batch 51.12
# |  1800/ 3600 batches | ms/batch 51.32
# |  2400/ 3600 batches | ms/batch 51.23
# |  3000/ 3600 batches | ms/batch 51.00
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 316.38s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 51.40
# |  1200/ 3600 batches | ms/batch 50.38
# |  1800/ 3600 batches | ms/batch 50.51
# |  2400/ 3600 batches | ms/batch 50.49
# |  3000/ 3600 batches | ms/batch 50.62
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 313.20s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.84
# |  1200/ 3600 batches | ms/batch 50.44
# |  1800/ 3600 batches | ms/batch 50.59
# |  2400/ 3600 batches | ms/batch 50.44
# |  3000/ 3600 batches | ms/batch 50.53
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 312.60s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.94
# |  1200/ 3600 batches | ms/batch 50.46
# |  1800/ 3600 batches | ms/batch 50.66
# |  2400/ 3600 batches | ms/batch 50.63
# |  3000/ 3600 batches | ms/batch 50.66
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 313.34s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.97
# |  1200/ 3600 batches | ms/batch 50.53
# |  1800/ 3600 batches | ms/batch 50.70
# |  2400/ 3600 batches | ms/batch 50.57
# |  3000/ 3600 batches | ms/batch 50.55
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 313.74s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.94
# |  1200/ 3600 batches | ms/batch 50.56
# |  1800/ 3600 batches | ms/batch 50.66
# |  2400/ 3600 batches | ms/batch 50.61
# |  3000/ 3600 batches | ms/batch 50.59
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 313.56s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 51.03
# |  1200/ 3600 batches | ms/batch 50.47
# |  1800/ 3600 batches | ms/batch 50.62
# |  2400/ 3600 batches | ms/batch 50.57
# |  3000/ 3600 batches | ms/batch 50.61
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 313.06s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 50.89
# |  1200/ 3600 batches | ms/batch 50.45
# |  1800/ 3600 batches | ms/batch 50.58
# |  2400/ 3600 batches | ms/batch 50.63
# |  3000/ 3600 batches | ms/batch 50.48
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 312.84s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 51.01
# |  1200/ 3600 batches | ms/batch 50.52
# |  1800/ 3600 batches | ms/batch 50.63
# |  2400/ 3600 batches | ms/batch 50.64
# |  3000/ 3600 batches | ms/batch 50.50
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 313.16s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 51.02
# |  1200/ 3600 batches | ms/batch 50.44
# |  1800/ 3600 batches | ms/batch 50.59
# |  2400/ 3600 batches | ms/batch 50.65
# |  3000/ 3600 batches | ms/batch 50.47
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 313.08s | test accuracy  1.00
# -----------------------------------------------------------------------------------------

# %%
model.eval()

for i in range(20):
    prompt, answers = data_test[i]
    prompt_tensor = torch.tensor(tokenizer.encode(prompt)).view((-1,1))
    output = generate(model, prompt_tensor, len(answers) + 1).view((1,-1))
    print(tokenizer.decode(output.tolist()[0]) + "\t actual result: " + answers)
# Out:
# 422+311=733[EOS]	 actual result: 733
# 645+238=883[EOS]	 actual result: 883
# 704+212=916[EOS]	 actual result: 916
# 367+325=692[EOS]	 actual result: 692
# 878+223=1101[EOS]	 actual result: 1101
# 841+462=1303[EOS]	 actual result: 1303
# 383+908=1291[EOS]	 actual result: 1291
# 542+484=1026[EOS]	 actual result: 1026
# 590+687=1277[EOS]	 actual result: 1277
# 066+988=1054[EOS]	 actual result: 1054
# 354+948=1302[EOS]	 actual result: 1302
# 782+151=933[EOS]	 actual result: 933
# 660+866=1526[EOS]	 actual result: 1526
# 738+419=1157[EOS]	 actual result: 1157
# 618+437=1055[EOS]	 actual result: 1055
# 985+343=1328[EOS]	 actual result: 1328
# 461+569=1030[EOS]	 actual result: 1030
# 861+561=1422[EOS]	 actual result: 1422
# 260+981=1241[EOS]	 actual result: 1241
# 085+095=180[EOS]	 actual result: 180

# %% [markdown]
# ## Step 6: GRPO with PPO

# %% [markdown]
# We kept the previous architecture and only changed the `compute_loss` and `train_vanilla_GRPO` functions with `compute_loss_ppo` and `train_GRPO_PPO`.

# %% [markdown]
# ### Reward functions (unchanged)

# %%
def accuracy_reward(output, answer):
    pattern = r"\[EOS\]"
    output = re.sub(pattern, "", output)
    pattern = r"(\[PAD\])*$"
    output = re.sub(pattern, "", output)
    return 1. if output == answer else 0.

def distance_accuracy_reward(output, answer):
    pattern = r"\[EOS\]"
    output = re.sub(pattern, "", output)
    pattern = r"(\[PAD\])*$"
    output = re.sub(pattern, "", output)
    int_output = int(output)
    int_answer = int(answer)
    return abs(int_output - int_answer) / max(int_output, int_answer)

def digit_accuracy_reward(output, answer):
    pattern = r"\[EOS\]"
    output = re.sub(pattern, "", output)
    pattern = r"(\[PAD\])*$"
    output = re.sub(pattern, "", output)
    return sum(c1 == c2 for (c1,c2) in zip(output, answer)) / max(len(output), len(answer))

def reward_format(output):
    pattern = r"\d+\[EOS\](\[PAD\])*$"
    return 1. if bool(re.match(pattern, output)) else 0.

# %% [markdown]
# ### Hyperparameters (unchanged)

# %%
epochs = 20
batch_size = 16
learning_rate = 1e-4
num_samples = 16
temperature = .8

reporting_per_epoch = 5
log_interval = len(data_train) // (reporting_per_epoch + 1)
assert(log_interval % batch_size == 0)

reward_fun = digit_accuracy_reward
reward_format = reward_format

# %% [markdown]
# ### Reward and advantage computation (unchanged)

# %%
def compute_rewards(text_outputs, answers):
    repeated_answers = [answer for answer in answers for _ in range(num_samples)]
    rewards = torch.tensor(
        [0.2 * reward_format(output) + 0.8 * reward_fun(output, answer)
         for output, answer in zip(text_outputs, repeated_answers)],
        dtype=torch.float32,
        device=device
    )
    return rewards

def calculate_grpo_advantages(rewards):
    # reshape rewards to group by prompt
    # compute mean and standard deviation for each prompt group
    mean_rewards = rewards.view(-1, num_samples).mean(dim=1)
    std_rewards = rewards.view(-1, num_samples).std(dim=1)
    # expand the means and stds to match the original flat rewards tensor shape
    mean_rewards = mean_rewards.repeat_interleave(num_samples, dim=0)
    std_rewards = std_rewards.repeat_interleave(num_samples, dim=0)
    # normalize rewards to get advantages
    advantages = (rewards - mean_rewards) / (std_rewards + 1e-5)
    return advantages

def compute_log_probs(model, outputs, prompt_length):
    logits, _ = model(outputs)
    # logits.shape = (prompt_length + answers_length + 1, batch_size * num_samples, vocab_size)

    # we only need the log probabilities for the new tokens
    # this introduces a shift: the logits for a position are the predictions for the next token
    logits = logits[prompt_length-1:-1, :, :]
    # logits.shape = (answers_length + 1, batch_size * num_samples, vocab_size)

    # convert raw logits into log probabilities along the vocabulary axis
    log_probs = F.log_softmax(logits, dim=-1)
    # log_probs.shape = (answers_length + 1, batch_size * num_samples, vocab_size)
    return log_probs

# %% [markdown]
# ### Loss, train and eval for PPO (changed)

# %%
def compute_loss_ppo(advantages, old_log_probs, new_log_probs, responses, clip_epsilon=0.2):
    # reshape responses from (answers_length + 1, batch_size * num_samples)
    # to (answers_length + 1, batch_size * num_samples, 1) for gathering
    responses = responses.unsqueeze(-1)  # (answers_length + 1, batch_size * num_samples, 1)
    
    selected_new_log_probs = new_log_probs.gather(dim=-1, index=responses).squeeze(-1)
    selected_old_log_probs = old_log_probs.gather(dim=-1, index=responses).squeeze(-1)
    
    # ratio = exp(new_log_prob - old_log_prob)
    ratios = torch.exp(selected_new_log_probs - selected_old_log_probs)
    clipped_ratios = torch.clamp(ratios, 1.0 - clip_epsilon, 1.0 + clip_epsilon)
    
    # PPO loss: -mean(min(ratio * adv, clipped_ratio * adv))
    loss = -torch.mean(torch.min(ratios * advantages.unsqueeze(0), clipped_ratios * advantages.unsqueeze(0)))
    return loss

# %%
def train_GRPO_PPO(verbose=False):
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    best_test_accuracy = None
    test_accuracy = evaluate()
    print('-' * 89)
    print('| initialisation | test accuracy {:5.2f}'.format(test_accuracy))
    print('-' * 89)

    # switch eval for train model (enables dropout)
    model.train()

    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        start_time = time.time()
        for batch, i in enumerate(range(0, len(data_train) - 1, batch_size)):

            # get a batch of prompts and answers
            prompts, _, prompt_length, answers_length, questions, answers = get_batch("train", i, batch_size)
            prompts = prompts.to(device) # (prompt_length, batch_size)

            # generate samples for each prompt
            outputs = generate(model,
                               prompts,
                               new_tokens=answers_length + 1,
                               mode="sampling",
                               num_samples=num_samples,
                               temperature=temperature)
            # outputs.shape = (prompt_length + answers_length + 1, batch_size * num_samples)
            text_outputs = [tokenizer.decode(outputs[prompt_length:, i].tolist())
                            for i in range(outputs.size(1))]

            # compute old log probabilities
            old_log_probs = compute_log_probs(model, outputs, prompt_length).detach()

            # compute rewards
            rewards = compute_rewards(text_outputs, answers)

            # compute advantages
            advantages = calculate_grpo_advantages(rewards)

            # compute new log probabilities
            new_log_probs = compute_log_probs(model, outputs, prompt_length)
            
            # compute loss
            responses = outputs[prompt_length:, :]
            loss = compute_loss_ppo(advantages, old_log_probs, new_log_probs, responses, clip_epsilon=0.2)

            # optimize
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            if i % log_interval == 0 and batch > 0:
                elapsed = time.time() - start_time
                print('| {:5d}/{:5d} batches | ms/batch {:5.2f}'.format(batch, len(data_train) // batch_size, elapsed))
                if verbose:
                    print("\nquestion:", questions[0],
                          "\nanswer:", answers[0],
                          "\noutput:", text_outputs[:num_samples],
                          "\nreward:", rewards[:num_samples],
                          "\nadvantage:", advantages[:num_samples], "\n")
                start_time = time.time()

        test_accuracy = evaluate()
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | test accuracy {:5.2f}'.format(epoch, (time.time() - epoch_start_time), test_accuracy))
        print('-' * 89)
        # Save the model if the test accuracy is the best we've seen so far.
        if best_test_accuracy is None or test_accuracy < best_test_accuracy:
            with open("arithmetic_GRPO_PPO.pt", 'wb') as f:
                torch.save(model, f)
            best_test_accuracy = test_accuracy

# %%
train_GRPO_PPO(verbose=False)
# Out:
# -----------------------------------------------------------------------------------------
# | initialisation | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 59.62
# |  1200/ 3600 batches | ms/batch 58.82
# |  1800/ 3600 batches | ms/batch 59.10
# |  2400/ 3600 batches | ms/batch 58.80
# |  3000/ 3600 batches | ms/batch 58.88
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 363.36s | test accuracy  0.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.81
# |  1200/ 3600 batches | ms/batch 55.30
# |  1800/ 3600 batches | ms/batch 55.39
# |  2400/ 3600 batches | ms/batch 55.45
# |  3000/ 3600 batches | ms/batch 55.41
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 342.21s | test accuracy  0.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.82
# |  1200/ 3600 batches | ms/batch 55.23
# |  1800/ 3600 batches | ms/batch 55.46
# |  2400/ 3600 batches | ms/batch 55.37
# |  3000/ 3600 batches | ms/batch 55.39
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 342.13s | test accuracy  0.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.81
# |  1200/ 3600 batches | ms/batch 55.30
# |  1800/ 3600 batches | ms/batch 55.58
# |  2400/ 3600 batches | ms/batch 55.45
# |  3000/ 3600 batches | ms/batch 55.49
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 344.29s | test accuracy  0.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 57.18
# |  1200/ 3600 batches | ms/batch 56.13
# |  1800/ 3600 batches | ms/batch 56.75
# |  2400/ 3600 batches | ms/batch 56.56
# |  3000/ 3600 batches | ms/batch 56.58
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 350.08s | test accuracy  0.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 57.10
# |  1200/ 3600 batches | ms/batch 55.65
# |  1800/ 3600 batches | ms/batch 55.59
# |  2400/ 3600 batches | ms/batch 55.49
# |  3000/ 3600 batches | ms/batch 55.50
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 344.15s | test accuracy  0.69
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.76
# |  1200/ 3600 batches | ms/batch 55.30
# |  1800/ 3600 batches | ms/batch 55.47
# |  2400/ 3600 batches | ms/batch 55.33
# |  3000/ 3600 batches | ms/batch 55.22
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 341.77s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.74
# |  1200/ 3600 batches | ms/batch 55.25
# |  1800/ 3600 batches | ms/batch 55.41
# |  2400/ 3600 batches | ms/batch 55.26
# |  3000/ 3600 batches | ms/batch 55.27
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 341.45s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.75
# |  1200/ 3600 batches | ms/batch 55.16
# |  1800/ 3600 batches | ms/batch 55.34
# |  2400/ 3600 batches | ms/batch 55.27
# |  3000/ 3600 batches | ms/batch 55.20
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 341.05s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.67
# |  1200/ 3600 batches | ms/batch 55.09
# |  1800/ 3600 batches | ms/batch 55.36
# |  2400/ 3600 batches | ms/batch 55.20
# |  3000/ 3600 batches | ms/batch 55.30
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 341.12s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.70
# |  1200/ 3600 batches | ms/batch 55.07
# |  1800/ 3600 batches | ms/batch 55.39
# |  2400/ 3600 batches | ms/batch 55.12
# |  3000/ 3600 batches | ms/batch 55.20
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 340.87s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.72
# |  1200/ 3600 batches | ms/batch 55.05
# |  1800/ 3600 batches | ms/batch 55.26
# |  2400/ 3600 batches | ms/batch 55.07
# |  3000/ 3600 batches | ms/batch 55.15
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 340.58s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.76
# |  1200/ 3600 batches | ms/batch 55.33
# |  1800/ 3600 batches | ms/batch 55.46
# |  2400/ 3600 batches | ms/batch 55.33
# |  3000/ 3600 batches | ms/batch 55.24
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 341.81s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.81
# |  1200/ 3600 batches | ms/batch 55.24
# |  1800/ 3600 batches | ms/batch 55.50
# |  2400/ 3600 batches | ms/batch 55.37
# |  3000/ 3600 batches | ms/batch 55.40
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 341.93s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.81
# |  1200/ 3600 batches | ms/batch 55.30
# |  1800/ 3600 batches | ms/batch 55.34
# |  2400/ 3600 batches | ms/batch 55.34
# |  3000/ 3600 batches | ms/batch 55.50
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 341.96s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.71
# |  1200/ 3600 batches | ms/batch 55.23
# |  1800/ 3600 batches | ms/batch 55.44
# |  2400/ 3600 batches | ms/batch 55.32
# |  3000/ 3600 batches | ms/batch 55.32
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 342.08s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.72
# |  1200/ 3600 batches | ms/batch 55.21
# |  1800/ 3600 batches | ms/batch 55.40
# |  2400/ 3600 batches | ms/batch 55.35
# |  3000/ 3600 batches | ms/batch 55.29
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 341.55s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.74
# |  1200/ 3600 batches | ms/batch 55.15
# |  1800/ 3600 batches | ms/batch 55.39
# |  2400/ 3600 batches | ms/batch 55.22
# |  3000/ 3600 batches | ms/batch 55.29
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 341.32s | test accuracy  1.00
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.80
# |  1200/ 3600 batches | ms/batch 55.19
# |  1800/ 3600 batches | ms/batch 55.43
# |  2400/ 3600 batches | ms/batch 55.33
# |  3000/ 3600 batches | ms/batch 55.27
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 341.50s | test accuracy  0.99
# -----------------------------------------------------------------------------------------
# |   600/ 3600 batches | ms/batch 55.75
# |  1200/ 3600 batches | ms/batch 55.01
# |  1800/ 3600 batches | ms/batch 55.19
# |  2400/ 3600 batches | ms/batch 55.03
# |  3000/ 3600 batches | ms/batch 54.95
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 340.08s | test accuracy  1.00
# -----------------------------------------------------------------------------------------

# %%
model.eval()

for i in range(20):
    prompt, answers = data_test[i]
    prompt_tensor = torch.tensor(tokenizer.encode(prompt)).view((-1, 1)).to(device)
    output = generate(model, prompt_tensor, len(answers) + 1).view((1, -1))
    print(tokenizer.decode(output.tolist()[0]) + "\t actual result: " + answers)
# Out:
# 422+311=733[EOS]	 actual result: 733
# 645+238=883[EOS]	 actual result: 883
# 704+212=916[EOS]	 actual result: 916
# 367+325=693[EOS]	 actual result: 692
# 878+223=1101[EOS]	 actual result: 1101
# 841+462=1303[EOS]	 actual result: 1303
# 383+908=1291[EOS]	 actual result: 1291
# 542+484=1026[EOS]	 actual result: 1026
# 590+687=1277[EOS]	 actual result: 1277
# 066+988=1054[EOS]	 actual result: 1054
# 354+948=1302[EOS]	 actual result: 1302
# 782+151=933[EOS]	 actual result: 933
# 660+866=1526[EOS]	 actual result: 1526
# 738+419=1157[EOS]	 actual result: 1157
# 618+437=1055[EOS]	 actual result: 1055
# 985+343=1328[EOS]	 actual result: 1328
# 461+569=1030[EOS]	 actual result: 1030
# 861+561=1422[EOS]	 actual result: 1422
# 260+981=1241[EOS]	 actual result: 1241
# 085+095=180[EOS]	 actual result: 180

# %% [markdown]
# ## Conclusion
#
# The GRPO with PPO is a bit slower per batch because of the extra ratio and clipping calculations. However, it reaches 1.0 accuracy after 7 epochs, while vanilla GRPO takes 10 epochs to get there.
#
# That said, PPO stays at 0 accuracy for the first 5 epochs, while vanilla already hits 0.99 after just 2 epochs. PPO takes longer to start improving but reaches the best accuracy faster (fewer epochs).
